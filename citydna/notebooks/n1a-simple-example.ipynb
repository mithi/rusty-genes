# %%
from helpers import simulate

# %%
simulate("../data/cities/cities0.csv", "../data/output/output0.csv", sleep=0.2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f6f900a1-6e28-4cdc-b37b-5442f449b3b3">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="fb2aaa39-1de8-4ef3-af2f-4e102e8fc980"></div>
# FINAL champion score: 0.125 challenger score: 0.125
# done!

# %%
simulate("../data/cities/citiesA.csv", "../data/output/outputA.csv", sleep=0.1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1d676cff-81fa-4ed7-82e5-ce6f4f0513d9">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b2e49abd-d3e6-416e-9725-3a962612273e"></div>
# FINAL champion score: 0.0054764533758802645 challenger score: 0.004714704838283541
# done!

# %%
simulate("../data/cities/citiesB.csv", "../data/output/outputB.csv", sleep=0.1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="25a42b6c-a9c2-473e-a8ac-b86812fc03d7">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a1810942-0581-4d9a-b4f9-5aaa7931f9a9"></div>
# FINAL champion score: 0.011869950337615367 challenger score: 0.007221753836119487
# done!

# %%
simulate("../data/cities/citiesC.csv", "../data/output/outputC.csv", sleep=0.1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="43e7d121-2140-4220-8c0d-eed576388860">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="dfd414e2-6687-4cf5-85a1-c5d4f90d7845"></div>
# FINAL champion score: 0.05141874136299251 challenger score: 0.0465500233844839
# done!
