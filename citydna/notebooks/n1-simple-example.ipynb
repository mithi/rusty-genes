# %%
from helpers import simulate

# %%
simulate("../data/cities/cities0.csv", "../data/output/output0.csv", sleep=0.0)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="565c30a7-6e06-437a-ab14-d372b1bde64b">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="392aa074-6533-4535-8eb3-5a792ba00370"></div>
# </div>
# FINAL champion score: 0.125 challenger score: 0.125
# done!

# %%
simulate("../data/cities/citiesA.csv", "../data/output/outputA.csv", sleep=0.15)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f7c9cb59-73b0-43fd-a8be-7b7c6892f83d">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="4c46909a-636d-40be-9bff-0be69ad77b87"></div>
# </div>
# FINAL champion score: 0.00590092262770861 challenger score: 0.004473596609675731
# done!

# %%
simulate("../data/cities/citiesB.csv", "../data/output/outputB.csv", sleep=0.2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c5b10abd-6c12-4b46-9785-e792d0ad6347">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="8d3a2c5f-c7a6-4067-938a-45e584e75e7f"></div>
# </div>
# FINAL champion score: 0.012493553191811639 challenger score: 0.00744674657514593
# done!

# %%
simulate("../data/cities/citiesC.csv", "../data/output/outputC.csv", sleep=0.15)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2cdbbda4-476b-47cc-82e8-886af3dc6b19">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="dc619444-69e1-4697-96d7-45bd9a80089f"></div>
# </div>
# FINAL champion score: 0.05840148418129287 challenger score: 0.0446034104471077
# done!
