# %%
from helpers import simulate

# %%
simulate("../data/cities/citiesZ.csv", "../data/output/outputZ.csv", sleep=0.2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="58f631b3-6ea7-40b7-87b1-7c7b5782ff4b">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="bd005853-85b2-4d46-9410-d3bbcbd55c38"></div>
# FINAL champion score: 0.0417601808589091 challenger score: 0.0338252243075178
# done!

# %%
simulate("../data/cities/citiesY.csv", "../data/output/outputY.csv", sleep=0.2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="03ccac24-f686-4201-bc10-413326af4024">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="08044a77-6ca9-4fe0-a2c5-7338583ff33a"></div>
# FINAL champion score: 0.01454600038168432 challenger score: 0.013359641637539246
# done!

# %%
simulate("../data/cities/citiesX.csv", "../data/output/outputX.csv", sleep=0.1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7a407694-9c22-4010-8b73-ce0f7e3e6723">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9e5326b8-4e4e-4d91-a6f2-2031def66039"></div>
# FINAL champion score: 0.0037619768807978476 challenger score: 0.0034621586637860265
# done!
